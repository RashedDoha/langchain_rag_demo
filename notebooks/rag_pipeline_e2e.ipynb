# %%
from dotenv import load_dotenv
import os
load_dotenv()
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

# %%
model = init_chat_model('anthropic:claude-sonnet-4-6', temperature=1)

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
prompt = ChatPromptTemplate.from_template(
    "Write a short story about a {subject}."
)
chain = prompt | model | StrOutputParser()
response = chain.invoke({"subject": "cat"})

# %%
from pprint import pprint

# %%
pprint(response)
# Out:
# ('# The Windowsill\n'
#  '\n'
#  'Marmalade had claimed the windowsill three years ago, and she saw no reason '
#  'to give it up now.\n'
#  '\n'
#  'She watched the street below with the quiet authority of someone who owned '
#  'everything she surveyed — the oak tree, the mailbox, the neighbor who always '
#  'walked his nervous little dog at precisely eight in the morning. She had '
#  'catalogued them all.\n'
#  '\n'
#  'When the new family moved in across the street, Marmalade paid close '
#  'attention. There were children. She had opinions about children.\n'
#  '\n'
#  'For two weeks she observed them — their bicycles, their shouting, their '
#  'habit of leaving the gate open. Then one afternoon, the smallest one, a girl '
#  'with red rubber boots, stopped on the sidewalk and looked directly up at the '
#  'window.\n'
#  '\n'
#  '"Cat," the girl said simply.\n'
#  '\n'
#  'Marmalade stared back.\n'
#  '\n'
#  'The girl waved.\n'
#  '\n'
# ...

# %%
from ..src.rag.prompts import format_rag_user_prompt

prompt = format_rag_user_prompt(
    context="Their are 6 apples in total. 3 of them are red and 3 of them are green.",
    question="How many apples are red?",
)

print(prompt)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 from ..src.rag.prompts import format_rag_user_prompt
#       2
#       3 prompt = format_rag_user_prompt(
#       4     context="Their are 6 apples in total. 3 of them are red and 3 of them are green.",
#
# ImportError: attempted relative import with no known parent package

# %%
from pathlib import Path
import sys

src = Path.cwd().parent / "src"
sys.path.insert(0, str(src))

from rag.prompts import format_rag_user_prompt

# %%
format_rag_user_prompt(
    context="Their are 6 apples in total. 3 of them are red and 3 of them are green.",
    question="How many apples are red?",
)
# Out:
# 'Use the following retrieved context to answer the question.\n\nContext:\nTheir are 6 apples in total. 3 of them are red and 3 of them are green.\n\nQuestion:\nHow many apples are red?\n'

# %%
prompt = format_rag_user_prompt(
    context="Their are 6 apples in total. 3 of them are red and 3 of them are green.",
    question="How many apples are red?",
)

response = model.invoke(prompt)
print(response)
# Out:
# content='Based on the provided context, there are **3 red apples**.' additional_kwargs={} response_metadata={'id': 'msg_01D1Yr8FwVhMezK5hhAY7rXn', 'container': None, 'model': 'claude-sonnet-4-6', 'stop_details': None, 'stop_reason': 'end_turn', 'stop_sequence': None, 'usage': {'cache_creation': {'ephemeral_1h_input_tokens': 0, 'ephemeral_5m_input_tokens': 0}, 'cache_creation_input_tokens': 0, 'cache_read_input_tokens': 0, 'inference_geo': 'global', 'input_tokens': 58, 'output_tokens': 18, 'server_tool_use': None, 'service_tier': 'standard'}, 'model_name': 'claude-sonnet-4-6', 'model_provider': 'anthropic'} id='lc_run--019d4f0e-aa1b-7d70-8efb-9e36be59fae2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 58, 'output_tokens': 18, 'total_tokens': 76, 'input_token_details': {'cache_read': 0, 'cache_creation': 0, 'ephemeral_5m_input_tokens': 0, 'ephemeral_1h_input_tokens': 0}}

# %%
response.response_metadata['usage']
# Out:
# {'cache_creation': {'ephemeral_1h_input_tokens': 0,
#   'ephemeral_5m_input_tokens': 0},
#  'cache_creation_input_tokens': 0,
#  'cache_read_input_tokens': 0,
#  'inference_geo': 'global',
#  'input_tokens': 58,
#  'output_tokens': 18,
#  'server_tool_use': None,
#  'service_tier': 'standard'}
